# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules
import copy

# %% [markdown]
# ## Document
#
# [mlxtend.frequent_patterns](http://rasbt.github.io/mlxtend/api_subpackages/mlxtend.frequent_patterns/)

# %%
data = pd.read_excel('datasets/Online_Retail.xlsx')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
tmp_data = copy.deepcopy(data)

# %%
# clean data
# Stripping extra spaces in the description 
data['Description'] = data['Description'].str.strip() 
  
# Dropping the rows without any invoice number 
data.dropna(axis = 0, subset =['InvoiceNo'], inplace = True) 
data['InvoiceNo'] = data['InvoiceNo'].astype('str') 
  
# Dropping all transactions which were done on credit 
data = data[~data['InvoiceNo'].str.contains('C')]

# %%
# Transactions done in France 
basket_France = (data[data['Country'] =="France"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo')) 
  
# Transactions done in the United Kingdom 
basket_UK = (data[data['Country'] =="United Kingdom"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo')) 
  
# Transactions done in Portugal 
basket_Por = (data[data['Country'] =="Portugal"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo')) 
  
basket_Sweden = (data[data['Country'] =="Sweden"] 
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))

# %%
basket_UK.head()
# Out:
# Description  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# InvoiceNo
# 536365                         0.0                      0.0
# 536366                         0.0                      0.0
# 536367                         0.0                      0.0
# 536368                         0.0                      0.0
# 536369                         0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536365                          0.0                         0.0
# 536366                          0.0                         0.0
# 536367                          0.0                         0.0
# 536368                          0.0                         0.0
# 536369                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536365                             0.0                        0.0
# 536366                             0.0                        0.0
# 536367                             0.0                        0.0
# 536368                             0.0                        0.0
# 536369                             0.0                        0.0
#
# Description  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536365                                0.0                               0.0
# 536366                                0.0                               0.0
# 536367                                0.0                               0.0
# 536368                                0.0                               0.0
# 536369                                0.0                               0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536365                                   0.0                            0.0
# 536366                                   0.0                            0.0
# 536367                                   0.0                            0.0
# 536368                                   0.0                            0.0
# 536369                                   0.0                            0.0
#
# Description  ...  wrongly coded 20713  wrongly coded 23343  \
# InvoiceNo    ...
# 536365       ...                  0.0                  0.0
# 536366       ...                  0.0                  0.0
# 536367       ...                  0.0                  0.0
# 536368       ...                  0.0                  0.0
# 536369       ...                  0.0                  0.0
#
# Description  wrongly coded-23343  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                       0.0             0.0                   0.0
# 536366                       0.0             0.0                   0.0
# 536367                       0.0             0.0                   0.0
# 536368                       0.0             0.0                   0.0
# 536369                       0.0             0.0                   0.0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
#
# [5 rows x 4175 columns]

# %%
# Defining the hot encoding function to make the data suitable  
# for the concerned libraries 
def hot_encode(x): 
    if(x<= 0): 
        return 0
    if(x>= 1): 
        return 1
  # Encoding the datasets 
basket_encoded = basket_France.applymap(hot_encode) 
basket_France = basket_encoded 
  
basket_encoded = basket_UK.applymap(hot_encode) 
basket_UK = basket_encoded 
  
basket_encoded = basket_Por.applymap(hot_encode) 
basket_Por = basket_encoded 
  
basket_encoded = basket_Sweden.applymap(hot_encode) 
basket_Sweden = basket_encoded

# %%
# Building the model 
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True) 
  
# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules
# Out:
#                                            antecedents  \
# 44                        (JUMBO BAG WOODLAND ANIMALS)
# 258  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 270  (RED TOADSTOOL LED NIGHT LIGHT, PLASTERS IN TI...
# 301  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 302  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# ..                                                 ...
# 37                                           (POSTAGE)
# 26                                           (POSTAGE)
# 97                                           (POSTAGE)
# 227                                          (POSTAGE)
# 215                                          (POSTAGE)
#
#                                            consequents  antecedent support  \
# 44                                           (POSTAGE)            0.076531
# 258                                          (POSTAGE)            0.051020
# 270                                          (POSTAGE)            0.053571
# 301                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 302                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ..                                                 ...                 ...
# 37                            (JAM MAKING SET PRINTED)            0.765306
# 26                   (CIRCUS PARADE CHILDRENS EGG CUP)            0.765306
# 97                                     (PARTY BUNTING)            0.765306
# 227      (LUNCH BAG WOODLAND, LUNCH BAG RED RETROSPOT)            0.765306
# 215  (LUNCH BAG APPLE DESIGN, LUNCH BAG SPACEBOY DE...            0.765306
#
#      consequent support   support  confidence      lift  leverage  conviction
# 44             0.765306  0.076531    1.000000  1.306667  0.017961         inf
# 258            0.765306  0.051020    1.000000  1.306667  0.011974         inf
# 270            0.765306  0.053571    1.000000  1.306667  0.012573         inf
# 301            0.127551  0.099490    0.975000  7.644000  0.086474   34.897959
# 302            0.137755  0.099490    0.975000  7.077778  0.085433   34.489796
# ..                  ...       ...         ...       ...       ...         ...
# 37             0.053571  0.051020    0.066667  1.244444  0.010022    1.014031
# 26             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 97             0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 227            0.056122  0.051020    0.066667  1.187879  0.008070    1.011297
# 215            0.063776  0.051020    0.066667  1.045333  0.002213    1.003098
#
# [348 rows x 9 columns]

# %%
frq_items = apriori(basket_UK, min_support = 0.02, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules
# Out:
#                                            antecedents  \
# 166  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# 164  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 27                    (PINK REGENCY TEACUP AND SAUCER)
# 172  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 146                   (PINK REGENCY TEACUP AND SAUCER)
# ..                                                 ...
# 179                          (JUMBO BAG RED RETROSPOT)
# 137               (WHITE HANGING HEART T-LIGHT HOLDER)
# 160               (WHITE HANGING HEART T-LIGHT HOLDER)
# 144               (WHITE HANGING HEART T-LIGHT HOLDER)
# 34                (WHITE HANGING HEART T-LIGHT HOLDER)
#
#                                            consequents  antecedent support  \
# 166                  (GREEN REGENCY TEACUP AND SAUCER)            0.029249
# 164                  (ROSES REGENCY TEACUP AND SAUCER)            0.030910
# 27                   (GREEN REGENCY TEACUP AND SAUCER)            0.037660
# 172                          (JUMBO BAG RED RETROSPOT)            0.027053
# 146                  (ROSES REGENCY TEACUP AND SAUCER)            0.037660
# ..                                                 ...                 ...
# 179  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO STOR...            0.103820
# 137                   (NATURAL SLATE HEART CHALKBOARD)            0.116034
# 160                (WOODEN PICTURE FRAME WHITE FINISH)            0.116034
# 144                                    (PARTY BUNTING)            0.116034
# 34                             (HEART OF WICKER SMALL)            0.116034
#
#      consequent support   support  confidence       lift  leverage  conviction
# 166            0.050035  0.026410    0.902930  18.046041  0.024947    9.786434
# 164            0.051267  0.026410    0.854419  16.666089  0.024826    6.516893
# 27             0.050035  0.030910    0.820768  16.403939  0.029026    5.300203
# 172            0.103820  0.021696    0.801980   7.724749  0.018887    4.525711
# 146            0.051267  0.029249    0.776671  15.149556  0.027319    4.248149
# ..                  ...       ...         ...        ...       ...         ...
# 179            0.027482  0.020571    0.198142   7.209989  0.017718    1.212832
# 137            0.065302  0.021964    0.189289   2.898653  0.014387    1.152936
# 160            0.057642  0.021642    0.186519   3.235826  0.014954    1.158427
# 144            0.085391  0.020250    0.174515   2.043711  0.010341    1.107966
# 34             0.062356  0.020089    0.173130   2.776479  0.012854    1.133968
#
# [182 rows x 9 columns]

# %%
frq_items = apriori(basket_Por, min_support = 0.1, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules
# Out:
#                                            antecedents  \
# 67                   (SCANDINAVIAN PAISLEY PICNIC BAG)
# 204  (SCANDINAVIAN PAISLEY PICNIC BAG, LUNCH BAG RE...
# 209  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 280  (LUNCH BAG PINK POLKADOT, JUMBO SHOPPER VINTAG...
# 282  (LUNCH BAG PINK POLKADOT, JUMBO BAG PINK VINTA...
# ..                                                 ...
# 78                   (RETROSPOT TEA SET CERAMIC 11 PC)
# 62                   (RETROSPOT TEA SET CERAMIC 11 PC)
# 63                           (LUNCH BAG RED RETROSPOT)
# 1                                            (POSTAGE)
# 81                                           (POSTAGE)
#
#                                            consequents  antecedent support  \
# 67                   (PINK VINTAGE PAISLEY PICNIC BAG)            0.120690
# 204                  (PINK VINTAGE PAISLEY PICNIC BAG)            0.103448
# 209                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.103448
# 280  (JUMBO BAG SCANDINAVIAN BLUE PAISLEY, JUMBO BA...            0.103448
# 282  (JUMBO SHOPPER VINTAGE RED PAISLEY, JUMBO BAG ...            0.103448
# ..                                                 ...                 ...
# 78                   (PLASTERS IN TIN VINTAGE PAISLEY)            0.241379
# 62                           (LUNCH BAG RED RETROSPOT)            0.241379
# 63                   (RETROSPOT TEA SET CERAMIC 11 PC)            0.241379
# 1                       (BAKING SET 9 PIECE RETROSPOT)            0.517241
# 81                              (RECIPE BOX RETROSPOT)            0.517241
#
#      consequent support   support  confidence      lift  leverage  conviction
# 67             0.137931  0.120690    1.000000  7.250000  0.104043         inf
# 204            0.137931  0.103448    1.000000  7.250000  0.089180         inf
# 209            0.137931  0.103448    1.000000  7.250000  0.089180         inf
# 280            0.137931  0.103448    1.000000  7.250000  0.089180         inf
# 282            0.137931  0.103448    1.000000  7.250000  0.089180         inf
# ..                  ...       ...         ...       ...       ...         ...
# 78             0.172414  0.103448    0.428571  2.485714  0.061831    1.448276
# 62             0.241379  0.103448    0.428571  1.775510  0.045184    1.327586
# 63             0.241379  0.103448    0.428571  1.775510  0.045184    1.327586
# 1              0.206897  0.137931    0.266667  1.288889  0.030916    1.081505
# 81             0.137931  0.103448    0.200000  1.450000  0.032105    1.077586
#
# [318 rows x 9 columns]

# %%
frq_items = apriori(basket_Sweden, min_support = 0.07, use_colnames = True) 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False]) 
rules
# Out:
#                         antecedents  \
# 12      (TREASURE TIN BUFFALO BILL)
# 13        (BUBBLEGUM RING ASSORTED)
# 14   (TREASURE TIN GYMKHANA DESIGN)
# 15        (BUBBLEGUM RING ASSORTED)
# 32     (MAGIC DRAWING SLATE PURDEY)
# ..                              ...
# 180                       (POSTAGE)
# 187                       (POSTAGE)
# 193                       (POSTAGE)
# 71                        (POSTAGE)
# 77                        (POSTAGE)
#
#                                            consequents  antecedent support  \
# 12                           (BUBBLEGUM RING ASSORTED)            0.083333
# 13                         (TREASURE TIN BUFFALO BILL)            0.083333
# 14                           (BUBBLEGUM RING ASSORTED)            0.083333
# 15                      (TREASURE TIN GYMKHANA DESIGN)            0.083333
# 32                    (MAGIC DRAWING SLATE DOLLY GIRL)            0.083333
# ..                                                 ...                 ...
# 180  (RED TOADSTOOL LED NIGHT LIGHT, RABBIT NIGHT L...            0.611111
# 187  (WALL TIDY RETROSPOT, RED RETROSPOT CHARLOTTE ...            0.611111
# 193  (RED TOADSTOOL LED NIGHT LIGHT, WALL TIDY RETR...            0.611111
# 71                 (ROUND SNACK BOXES SET OF 4 FRUITS)            0.611111
# 77                         (WOODEN OWLS LIGHT GARLAND)            0.611111
#
#      consequent support   support  confidence       lift  leverage  conviction
# 12             0.083333  0.083333    1.000000  12.000000  0.076389         inf
# 13             0.083333  0.083333    1.000000  12.000000  0.076389         inf
# 14             0.083333  0.083333    1.000000  12.000000  0.076389         inf
# 15             0.083333  0.083333    1.000000  12.000000  0.076389         inf
# 32             0.083333  0.083333    1.000000  12.000000  0.076389         inf
# ..                  ...       ...         ...        ...       ...         ...
# 180            0.083333  0.083333    0.136364   1.636364  0.032407    1.061404
# 187            0.083333  0.083333    0.136364   1.636364  0.032407    1.061404
# 193            0.083333  0.083333    0.136364   1.636364  0.032407    1.061404
# 71             0.111111  0.083333    0.136364   1.227273  0.015432    1.029240
# 77             0.111111  0.083333    0.136364   1.227273  0.015432    1.029240
#
# [228 rows x 9 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
fpg = fpgrowth(basket_France,min_support = 0.1,use_colnames = True)
fpg.head()
# Out:
#     support                              itemsets
# 0  0.765306                             (POSTAGE)
# 1  0.181122       (RED TOADSTOOL LED NIGHT LIGHT)
# 2  0.158163  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  0.125000                  (SPACEBOY LUNCH BOX)
# 4  0.104592              (MINI PAINT SET VINTAGE)

# %%
association_rules(fpg)
# Out:
#                                           antecedents  \
# 0                     (RED TOADSTOOL LED NIGHT LIGHT)
# 1                (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2                  (LUNCH BOX WITH CUTLERY RETROSPOT)
# 3                          (RED RETROSPOT MINI CASES)
# 4                                (LUNCH BAG WOODLAND)
# 5                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 6                          (PLASTERS IN TIN SPACEBOY)
# 7                          (REGENCY CAKESTAND 3 TIER)
# 8                 (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 9                       (SET/6 RED SPOTTY PAPER CUPS)
# 10                      (SET/6 RED SPOTTY PAPER CUPS)
# 11                    (SET/6 RED SPOTTY PAPER PLATES)
# 12                    (SET/6 RED SPOTTY PAPER PLATES)
# 13                    (SET/6 RED SPOTTY PAPER PLATES)
# 14  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 15             (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)
# 16           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                    (PLASTERS IN TIN CIRCUS PARADE)
# 19               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 20                           (LUNCH BAG APPLE DESIGN)
# 21                               (RABBIT NIGHT LIGHT)
#
#                                consequents  antecedent support  \
# 0                                (POSTAGE)            0.181122
# 1                                (POSTAGE)            0.158163
# 2                                (POSTAGE)            0.142857
# 3                                (POSTAGE)            0.137755
# 4                                (POSTAGE)            0.117347
# 5                                (POSTAGE)            0.170918
# 6                                (POSTAGE)            0.137755
# 7                                (POSTAGE)            0.125000
# 8                                (POSTAGE)            0.122449
# 9                                (POSTAGE)            0.137755
# 10         (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 11           (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 12                               (POSTAGE)            0.127551
# 13    (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 14                               (POSTAGE)            0.122449
# 15         (SET/6 RED SPOTTY PAPER PLATES)            0.117347
# 16           (SET/6 RED SPOTTY PAPER CUPS)            0.107143
# 17  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE)            0.127551
# 18                               (POSTAGE)            0.168367
# 19                               (POSTAGE)            0.132653
# 20                               (POSTAGE)            0.125000
# 21                               (POSTAGE)            0.188776
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.765306  0.158163    0.873239  1.141033  0.019549    1.851474
# 1             0.765306  0.147959    0.935484  1.222366  0.026916    3.637755
# 2             0.765306  0.114796    0.803571  1.050000  0.005466    1.194805
# 3             0.765306  0.114796    0.833333  1.088889  0.009371    1.408163
# 4             0.765306  0.102041    0.869565  1.136232  0.012234    1.799320
# 5             0.765306  0.137755    0.805970  1.053134  0.006950    1.209576
# 6             0.765306  0.114796    0.833333  1.088889  0.009371    1.408163
# 7             0.765306  0.104592    0.836735  1.093333  0.008929    1.437500
# 8             0.765306  0.114796    0.937500  1.225000  0.021085    3.755102
# 9             0.765306  0.117347    0.851852  1.113086  0.011922    1.584184
# 10            0.127551  0.122449    0.888889  6.968889  0.104878    7.852041
# 11            0.137755  0.122449    0.960000  6.968889  0.104878   21.556122
# 12            0.765306  0.107143    0.840000  1.097600  0.009527    1.466837
# 13            0.132653  0.102041    0.800000  6.030769  0.085121    4.336735
# 14            0.765306  0.102041    0.833333  1.088889  0.008330    1.408163
# 15            0.127551  0.102041    0.869565  6.817391  0.087073    6.688776
# 16            0.137755  0.102041    0.952381  6.913580  0.087281   18.107143
# 17            0.117347  0.102041    0.800000  6.817391  0.087073    4.413265
# 18            0.765306  0.147959    0.878788  1.148283  0.019107    1.936224
# 19            0.765306  0.109694    0.826923  1.080513  0.008174    1.356009
# 20            0.765306  0.104592    0.836735  1.093333  0.008929    1.437500
# 21            0.765306  0.165816    0.878378  1.147748  0.021345    1.929705
